# %%
import pandas as pd

url = "https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/BankChurners.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
# Count of missing values
df.isnull().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %%
# For numeric columns
df.describe()

# For categorical columns
df.describe(include='object')
# Out:
#            Attrition_Flag Gender Education_Level Marital_Status  \
# count               10127  10127           10127          10127
# unique                  2      2               7              4
# top     Existing Customer      F        Graduate        Married
# freq                 8500   5358            3128           4687
#
#        Income_Category Card_Category
# count            10127         10127
# unique               6             4
# top     Less than $40K          Blue
# freq              3561          9436

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x='Attrition_Flag', data=df)
plt.title("Customer Churn vs Existing")
plt.show()

# %%
sns.histplot(df['Customer_Age'], kde=True)
plt.title("Customer Age Distribution")
plt.show()

# %%
sns.countplot(x='Gender', data=df)
plt.title("Gender Distribution")
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
numeric_cols = ['Customer_Age', 'Credit_Limit', 'Total_Revolving_Bal', 'Total_Trans_Amt', 'Total_Trans_Ct']

mean_values = df[numeric_cols].mean()
print("📊 Mean:\n", mean_values)

median_values = df[numeric_cols].median()
print("\n📊 Median:\n", median_values)

variance_values = df[numeric_cols].var()
print("\n📊 Variance:\n", variance_values)
# Out:
# 📊 Mean:
#  Customer_Age             46.325960
# Credit_Limit           8631.953698
# Total_Revolving_Bal    1162.814061
# Total_Trans_Amt        4404.086304
# Total_Trans_Ct           64.858695
# dtype: float64
#
# 📊 Median:
#  Customer_Age             46.0
# Credit_Limit           4549.0
# Total_Revolving_Bal    1276.0
# Total_Trans_Amt        3899.0
# Total_Trans_Ct           67.0
# dtype: float64
#
# 📊 Variance:
#  Customer_Age           6.426931e+01
# Credit_Limit           8.260586e+07
# Total_Revolving_Bal    6.642044e+05
# Total_Trans_Amt        1.154049e+07
# Total_Trans_Ct         5.509616e+02
# dtype: float64

# %%
1. Dataset Overview:
   - Total Records: 10,127
   - Target Variable: `Attrition_Flag` (Existing or Attrited Customers)
   - No missing values found.

2. Descriptive Statistics:
   - Average Customer Age: ~46 years
   - Average Credit Limit: ~8,600


3. Insights from Visualizations:
   - Majority of customers are **Existing**, with fewer Attrited (churned).
   - Age and gender distributions are balanced.
   - Customers with higher transaction activity tend to stay.
   - Strong correlation observed between `Total_Trans_Ct` and `Total_Trans_Amt`.

4. Churn Behavior:
   - Churn tends to occur among customers with lower credit limits or fewer transactions.

This EDA provides foundational understanding for modeling churn prediction in the future.
